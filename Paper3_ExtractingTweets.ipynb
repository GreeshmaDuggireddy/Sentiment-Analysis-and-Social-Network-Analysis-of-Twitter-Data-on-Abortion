# %% [markdown]
# # Course: Social Media Mining
# # Paper - 3

# %% [markdown]
# ## Name: Greeshma Sai Sree Duggireddy

# %% [markdown]
# ## Extracting Data from Twitter through SNSCRAPE

# %% [markdown]
# ### Installing Libraries

# %%
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git
import os
import pandas as pd
import snscrape.modules.twitter as sntwitter
import itertools
# Out:
# ...
#   Cloning https://github.com/JustAnotherArchivist/snscrape.git to c:\users\greeshma sai sree\appdata\local\temp\pip-req-build-t88s7sxn
#   Resolved https://github.com/JustAnotherArchivist/snscrape.git to commit ed3ea944d177157d688786470c8369198b0ce8ce
# ...
#   Running command git clone -q https://github.com/JustAnotherArchivist/snscrape.git 'C:\Users\Greeshma Sai Sree\AppData\Local\Temp\pip-req-build-t88s7sxn'

# %% [markdown]
# ### #abortion Tweets

# %%
search = '"#abortion"'

scraped_tweets = sntwitter.TwitterSearchScraper(search).get_items()

sliced_scraped_tweets = itertools.islice(scraped_tweets, 1000)

df_abortion = pd.DataFrame(sliced_scraped_tweets)

# %%
df_abortion
# Out:
#                                                    url  \
# 0    https://twitter.com/arbriterfire/status/152057...
# 1    https://twitter.com/poorservant/status/1520564...
# 2    https://twitter.com/GodDBestAvenger/status/152...
# 3    https://twitter.com/wuttnotw/status/1520559328...
# 4    https://twitter.com/sempervirens117/status/152...
# ..                                                 ...
# 995  https://twitter.com/AbortionReviews/status/151...
# 996  https://twitter.com/HalleluYah1237/status/1518...
# 997  https://twitter.com/RealYeshua1/status/1518965...
# 998  https://twitter.com/sgszewczyk/status/15189648...
# 999  https://twitter.com/KeepLifeLegal/status/15189...
#
#                          date  \
# 0   2022-05-01 01:07:09+00:00
# 1   2022-05-01 00:43:23+00:00
# 2   2022-05-01 00:42:28+00:00
# 3   2022-05-01 00:22:49+00:00
# 4   2022-05-01 00:18:07+00:00
# ..                        ...
# 995 2022-04-26 14:50:24+00:00
# 996 2022-04-26 14:49:42+00:00
# ...

# %%
df_abortion.to_csv('df_abortion.csv', sep=',', index=False)

# %% [markdown]
# ### #abortion Tweets in USA

# %%
location = '40.267194,-86.134902,1000000mi'

scraped_tweets = sntwitter.TwitterSearchScraper('#abortion geocode:"{}"'.format(location)).get_items()

sliced_scraped_tweets = itertools.islice(scraped_tweets, 1000)

df_AbortionUSA = pd.DataFrame(sliced_scraped_tweets)

df_AbortionUSA['user_location'] =  df_AbortionUSA['user'].apply(lambda x: x['location'])

# %%
df_AbortionUSA
# Out:
#                                                    url  \
# 0    https://twitter.com/arbriterfire/status/152057...
# 1    https://twitter.com/poorservant/status/1520564...
# 2    https://twitter.com/Dame_ThugLife/status/15205...
# 3    https://twitter.com/BenBen_Show/status/1520538...
# 4    https://twitter.com/ar_ROCKETMAN/status/152053...
# ..                                                 ...
# 995  https://twitter.com/bentleybrian/status/135460...
# 996  https://twitter.com/DebD417/status/13540875025...
# 997  https://twitter.com/CatholicMascul1/status/135...
# 998  https://twitter.com/StephLSchmid/status/135373...
# 999  https://twitter.com/lifeguardone/status/135371...
#
#                          date  \
# 0   2022-05-01 01:07:09+00:00
# 1   2022-05-01 00:43:23+00:00
# 2   2022-04-30 23:21:10+00:00
# 3   2022-04-30 23:01:18+00:00
# 4   2022-04-30 22:40:00+00:00
# ..                        ...
# 995 2021-01-28 01:57:39+00:00
# 996 2021-01-26 15:23:13+00:00
# ...

# %%
df_AbortionUSA.to_csv('df_AbortionUNITEDSTATES.csv', sep=',', index=False)

# %% [markdown]
# ### #abortion Tweets in Ireland

# %%
location = '53.43333,-7.95,500mi'

scraped_tweets = sntwitter.TwitterSearchScraper('#abortion geocode:"{}"'.format(location)).get_items()

sliced_scraped_tweets = itertools.islice(scraped_tweets, 1000)

df_AbortionIreland = pd.DataFrame(sliced_scraped_tweets)

df_AbortionIreland['user_location'] =  df_AbortionIreland['user'].apply(lambda x: x['location'])

# %%
df_AbortionIreland
# Out:
#                                                    url  \
# 0    https://twitter.com/sodomhnaill34/status/15204...
# 1    https://twitter.com/Aine_o_Eire/status/1520340...
# 2    https://twitter.com/r0fficial/status/152031069...
# 3    https://twitter.com/StephaniePMcKea/status/152...
# 4    https://twitter.com/Sange1962/status/151999248...
# ..                                                 ...
# 995  https://twitter.com/TheSoulfulDoc/status/77798...
# 996  https://twitter.com/arielpayit4ward/status/777...
# 997  https://twitter.com/CatholicIreland/status/774...
# 998  https://twitter.com/PatrickCorrigan/status/774...
# 999  https://twitter.com/Ella_M_Whelan/status/77357...
#
#                          date  \
# 0   2022-04-30 14:28:27+00:00
# 1   2022-04-30 09:53:23+00:00
# 2   2022-04-30 07:54:50+00:00
# 3   2022-04-29 20:24:33+00:00
# 4   2022-04-29 10:50:24+00:00
# ..                        ...
# 995 2016-09-19 21:35:02+00:00
# 996 2016-09-18 11:05:52+00:00
# ...

# %%
df_AbortionIreland.to_csv('df_AbortionIRELAND.csv', sep=',', index=False)

# %% [markdown]
# ### abortion Tweets in Philippines

# %%
location = '12.06428,123.8958,2000mi'

scraped_tweets = sntwitter.TwitterSearchScraper('abortion geocode:"{}"'.format(location)).get_items()

sliced_scraped_tweets = itertools.islice(scraped_tweets, 1000)

df_AbortionPhilippines = pd.DataFrame(sliced_scraped_tweets)

df_AbortionPhilippines['user_location'] =  df_AbortionPhilippines['user'].apply(lambda x: x['location'])

# %%
df_AbortionPhilippines
# Out:
#                                                    url  \
# 0    https://twitter.com/demonick/status/1520566318...
# 1    https://twitter.com/Female_abortion/status/152...
# 2    https://twitter.com/TheHandgunGuy/status/15205...
# 3    https://twitter.com/JirenHan/status/1520559468...
# 4    https://twitter.com/Bonyen_Lee/status/15205593...
# ..                                                 ...
# 995  https://twitter.com/frncsclloyddd/status/12772...
# 996  https://twitter.com/Newmind0071/status/1277138...
# 997  https://twitter.com/chaeiseu/status/1276966474...
# 998  https://twitter.com/eyoungwah/status/127675306...
# 999  https://twitter.com/Beaulz1/status/12758762983...
#
#                          date  \
# 0   2022-05-01 00:50:35+00:00
# 1   2022-05-01 00:47:38+00:00
# 2   2022-05-01 00:34:30+00:00
# 3   2022-05-01 00:23:22+00:00
# 4   2022-05-01 00:22:43+00:00
# ..                        ...
# 995 2020-06-28 17:04:38+00:00
# 996 2020-06-28 07:15:23+00:00
# ...

# %%
df_AbortionPhilippines.to_csv('df_AbortionPHILIPPINES.csv', sep=',', index=False)
